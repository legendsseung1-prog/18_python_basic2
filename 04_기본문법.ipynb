# %%
# 세미콜론
print("Hello world");
# Out:
# Hello world

# %%
print("hello"); print("1234")
# Out:
# hello
# 1234

# %%
# 한 줄 주석
# 출력하라
print("hello world")
# Out:
# hello world

# %%
# 블록 주석
# 주석 필요한부분 드래그해서 컨트롤 /

# print("hello world")
# print("hello world")
# print("hello world")

# %%
# 들여쓰기
a = 5
if a == 10:
    print("10 입니다.")
    print("5 입니다.")
